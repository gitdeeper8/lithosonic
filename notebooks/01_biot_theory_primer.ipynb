# %% [markdown]
# # Biot Theory Primer
# ## LITHO-SONIC Tutorial 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from litho_physics.biot import BiotSolver, RockProperties

# %% [markdown]
# ## Introduction to Biot Theory
#
# Biot theory describes acoustic wave propagation in fluid-saturated porous media.
