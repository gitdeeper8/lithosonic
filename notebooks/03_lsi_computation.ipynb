# %% [markdown]
# # Computing the Lithospheric Stress Index
# ## LITHO-SONIC Tutorial 3

# %%
import numpy as np
from litho_physics.lsi import LithosphericStressIndex, compute_lsi, get_alert_level

# Example parameters from Kīlauea
params = {
    'b_c': 0.72,
    'z_c': 0.68,
    'f_n': 2.3,
    'alpha_att': 0.77,
    's_ae': 0.83
}

lsi = compute_lsi(params)
alert = get_alert_level(lsi)

print(f'LSI = {lsi:.3f}')
print(f'Alert Level: {alert}')
